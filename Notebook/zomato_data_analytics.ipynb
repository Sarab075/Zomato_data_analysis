# %%
import pandas as pd

df=pd.read_csv('zomato.csv')
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
df.shape
# Out:
# (51717, 17)

# %%
df.columns
# Out:
# Index(['url', 'address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df=df.drop('url',axis=1)
df.columns
# Out:
# Index(['address', 'name', 'online_order', 'book_table', 'rate', 'votes',
#        'phone', 'location', 'rest_type', 'dish_liked', 'cuisines',
#        'approx_cost(for two people)', 'reviews_list', 'menu_item',
#        'listed_in(type)', 'listed_in(city)'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      51717 non-null  object
#  1   name                         51717 non-null  object
#  2   online_order                 51717 non-null  object
#  3   book_table                   51717 non-null  object
#  4   rate                         43942 non-null  object
#  5   votes                        51717 non-null  int64
#  6   phone                        50509 non-null  object
#  7   location                     51696 non-null  object
#  8   rest_type                    51490 non-null  object
#  9   dish_liked                   23639 non-null  object
#  10  cuisines                     51672 non-null  object
#  11  approx_cost(for two people)  51371 non-null  object
#  12  reviews_list                 51717 non-null  object
# ...

# %%
df=df.drop('dish_liked',axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      51717 non-null  object
#  1   name                         51717 non-null  object
#  2   online_order                 51717 non-null  object
#  3   book_table                   51717 non-null  object
#  4   rate                         43942 non-null  object
#  5   votes                        51717 non-null  int64
#  6   phone                        50509 non-null  object
#  7   location                     51696 non-null  object
#  8   rest_type                    51490 non-null  object
#  9   cuisines                     51672 non-null  object
#  10  approx_cost(for two people)  51371 non-null  object
#  11  reviews_list                 51717 non-null  object
#  12  menu_item                    51717 non-null  object
# ...

# %%
df['rate'].head()
# Out:
# 0    4.1/5
# 1    4.1/5
# 2    3.8/5
# 3    3.7/5
# 4    3.8/5
# Name: rate, dtype: object

# %%
df2=df.duplicated()
df2
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51712    False
# 51713    False
# 51714    False
# 51715    False
# 51716    False
# Length: 51717, dtype: bool

# %%
df3=df.drop_duplicates()
df3
# Out:
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# 3      1st Floor, Annakuteera, 3rd Stage, Banashankar...
# 4      10, 3rd Floor, Lakshmi Associates, Gandhi Baza...
# ...                                                  ...
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51677 entries, 0 to 51716
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      51677 non-null  object
#  1   name                         51677 non-null  object
#  2   online_order                 51677 non-null  object
#  3   book_table                   51677 non-null  object
#  4   rate                         43910 non-null  object
#  5   votes                        51677 non-null  int64
#  6   phone                        50470 non-null  object
#  7   location                     51656 non-null  object
#  8   rest_type                    51450 non-null  object
#  9   cuisines                     51632 non-null  object
#  10  approx_cost(for two people)  51332 non-null  object
#  11  reviews_list                 51677 non-null  object
#  12  menu_item                    51677 non-null  object
# ...

# %%
df3=df3.rename(columns={'rate':'rating'})
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51677 entries, 0 to 51716
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      51677 non-null  object
#  1   name                         51677 non-null  object
#  2   online_order                 51677 non-null  object
#  3   book_table                   51677 non-null  object
#  4   rating                       43910 non-null  object
#  5   votes                        51677 non-null  int64
#  6   phone                        50470 non-null  object
#  7   location                     51656 non-null  object
#  8   rest_type                    51450 non-null  object
#  9   cuisines                     51632 non-null  object
#  10  approx_cost(for two people)  51332 non-null  object
#  11  reviews_list                 51677 non-null  object
#  12  menu_item                    51677 non-null  object
# ...

# %%
import pandasql as ps

df3 = df3.rename(columns={'listed_in(city)': 'listed_in_city'})
#df3=df3.drop('listed_in_city', axis=1)
df3.info()
query="select location from df3 ;"

df4=ps.sqldf(query,locals())
#df4
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51677 entries, 0 to 51716
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      51677 non-null  object
#  1   name                         51677 non-null  object
#  2   online_order                 51677 non-null  object
#  3   book_table                   51677 non-null  object
#  4   rating                       43910 non-null  object
#  5   votes                        51677 non-null  int64
#  6   phone                        50470 non-null  object
#  7   location                     51656 non-null  object
#  8   rest_type                    51450 non-null  object
#  9   cuisines                     51632 non-null  object
#  10  approx_cost(for two people)  51332 non-null  object
#  11  reviews_list                 51677 non-null  object
#  12  menu_item                    51677 non-null  object
# ...

# %%
df3=df3.drop('rest_type', axis=1)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51677 entries, 0 to 51716
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      51677 non-null  object
#  1   name                         51677 non-null  object
#  2   online_order                 51677 non-null  object
#  3   book_table                   51677 non-null  object
#  4   rating                       43910 non-null  object
#  5   votes                        51677 non-null  int64
#  6   phone                        50470 non-null  object
#  7   location                     51656 non-null  object
#  8   cuisines                     51632 non-null  object
#  9   approx_cost(for two people)  51332 non-null  object
#  10  reviews_list                 51677 non-null  object
#  11  menu_item                    51677 non-null  object
#  12  listed_in(type)              51677 non-null  object
# ...

# %%
df3=df3.drop('phone', axis=1)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51677 entries, 0 to 51716
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   address                      51677 non-null  object
#  1   name                         51677 non-null  object
#  2   online_order                 51677 non-null  object
#  3   book_table                   51677 non-null  object
#  4   rating                       43910 non-null  object
#  5   votes                        51677 non-null  int64
#  6   location                     51656 non-null  object
#  7   cuisines                     51632 non-null  object
#  8   approx_cost(for two people)  51332 non-null  object
#  9   reviews_list                 51677 non-null  object
#  10  menu_item                    51677 non-null  object
#  11  listed_in(type)              51677 non-null  object
#  12  listed_in_city               51677 non-null  object
# ...

# %%
df3=df3.rename(columns={'approx_cost(for two people)':'two_people_cost'})
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51677 entries, 0 to 51716
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   address          51677 non-null  object
#  1   name             51677 non-null  object
#  2   online_order     51677 non-null  object
#  3   book_table       51677 non-null  object
#  4   rating           43910 non-null  object
#  5   votes            51677 non-null  int64
#  6   location         51656 non-null  object
#  7   cuisines         51632 non-null  object
#  8   two_people_cost  51332 non-null  object
#  9   reviews_list     51677 non-null  object
#  10  menu_item        51677 non-null  object
#  11  listed_in(type)  51677 non-null  object
#  12  listed_in_city   51677 non-null  object
# dtypes: int64(1), object(12)
# memory usage: 5.5+ MB

# %%
df3=df3.drop('reviews_list', axis=1)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51677 entries, 0 to 51716
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   address          51677 non-null  object
#  1   name             51677 non-null  object
#  2   online_order     51677 non-null  object
#  3   book_table       51677 non-null  object
#  4   rating           43910 non-null  object
#  5   votes            51677 non-null  int64
#  6   location         51656 non-null  object
#  7   cuisines         51632 non-null  object
#  8   two_people_cost  51332 non-null  object
#  9   menu_item        51677 non-null  object
#  10  listed_in(type)  51677 non-null  object
#  11  listed_in_city   51677 non-null  object
# dtypes: int64(1), object(11)
# memory usage: 5.1+ MB

# %%
df3=df3.drop('menu_item', axis=1)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51677 entries, 0 to 51716
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   address          51677 non-null  object
#  1   name             51677 non-null  object
#  2   online_order     51677 non-null  object
#  3   book_table       51677 non-null  object
#  4   rating           43910 non-null  object
#  5   votes            51677 non-null  int64
#  6   location         51656 non-null  object
#  7   cuisines         51632 non-null  object
#  8   two_people_cost  51332 non-null  object
#  9   listed_in(type)  51677 non-null  object
#  10  listed_in_city   51677 non-null  object
# dtypes: int64(1), object(10)
# memory usage: 4.7+ MB

# %%
df3=df3.drop('listed_in(type)', axis=1)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51677 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   address          51677 non-null  object
#  1   name             51677 non-null  object
#  2   online_order     51677 non-null  object
#  3   book_table       51677 non-null  object
#  4   rating           43910 non-null  object
#  5   votes            51677 non-null  int64
#  6   location         51656 non-null  object
#  7   cuisines         51632 non-null  object
#  8   two_people_cost  51332 non-null  object
#  9   listed_in_city   51677 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 4.3+ MB

# %%
df3=df3.rename(columns={'listed_in_city':'type_of_restaurant'})
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51677 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   address             51677 non-null  object
#  1   name                51677 non-null  object
#  2   online_order        51677 non-null  object
#  3   book_table          51677 non-null  object
#  4   rating              43910 non-null  object
#  5   votes               51677 non-null  int64
#  6   location            51656 non-null  object
#  7   cuisines            51632 non-null  object
#  8   two_people_cost     51332 non-null  object
#  9   type_of_restaurant  51677 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 4.3+ MB

# %%
df3['rating']=df3['rating'].fillna(df3['rating'].mean)
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51677 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   address             51677 non-null  object
#  1   name                51677 non-null  object
#  2   online_order        51677 non-null  object
#  3   book_table          51677 non-null  object
#  4   rating              51677 non-null  object
#  5   votes               51677 non-null  int64
#  6   location            51656 non-null  object
#  7   cuisines            51632 non-null  object
#  8   two_people_cost     51332 non-null  object
#  9   type_of_restaurant  51677 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 4.3+ MB

# %%
df3=df3.dropna(subset=['location'])
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51656 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   address             51656 non-null  object
#  1   name                51656 non-null  object
#  2   online_order        51656 non-null  object
#  3   book_table          51656 non-null  object
#  4   rating              51656 non-null  object
#  5   votes               51656 non-null  int64
#  6   location            51656 non-null  object
#  7   cuisines            51632 non-null  object
#  8   two_people_cost     51332 non-null  object
#  9   type_of_restaurant  51656 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 4.3+ MB

# %%
df3=df3.dropna(subset=['cuisines','two_people_cost'])
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51313 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   address             51313 non-null  object
#  1   name                51313 non-null  object
#  2   online_order        51313 non-null  object
#  3   book_table          51313 non-null  object
#  4   rating              51313 non-null  object
#  5   votes               51313 non-null  int64
#  6   location            51313 non-null  object
#  7   cuisines            51313 non-null  object
#  8   two_people_cost     51313 non-null  object
#  9   type_of_restaurant  51313 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 4.3+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51313 entries, 0 to 51716
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   address             51313 non-null  object
#  1   name                51313 non-null  object
#  2   online_order        51313 non-null  object
#  3   book_table          51313 non-null  object
#  4   rating              51313 non-null  object
#  5   votes               51313 non-null  int64
#  6   location            51313 non-null  object
#  7   cuisines            51313 non-null  object
#  8   two_people_cost     51313 non-null  object
#  9   type_of_restaurant  51313 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 4.3+ MB

# %%
select jeans
from flipkart
where brand = 'levis' or brand= 'lee' and size=32 
order by price , rating dsc

# %%
select name 
from tinder
where age>18 and location=delhi and matches<1
order by age , name
